# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# time_scale is the no. of milliseconds between readings
time_scale = 20

# create some simulated time series data for user 1

base1 = (list(np.arange(-10,10, 1)) + list(np.arange(-9, 9, 1))[::-1]) * 7

ax_u1 = [ el + np.random.randint(-2, 3) for el in base1 ] 
ay_u1 = [ el + np.random.randint(-2, 3) for el in base1 ] 
az_u1 = [ el + np.random.randint(-2, 3) for el in base1 ]

# time_millis[i] = the system time when reading ax_u1[i] was taken, etc
time_millis_u1 = [ el * time_scale for el in list(range(0, len(ax_u1))) ]

# create simulated time series for user 2 which has a different base
# the idea is that user 2 takes less forceful steps (less acceleration) and their steps are faster

base2 = (list(np.arange(-7,7, 1)) + list(np.arange(-6, 6, 1))[::-1]) * 7
ax_u2 = [ el + np.random.randint(-2, 3) for el in base2 ] 
ay_u2 = [ el + np.random.randint(-2, 3) for el in base2 ] 
az_u2 = [ el + np.random.randint(-2, 3) for el in base2 ] 

time_millis_u2 = [ el * time_scale for el in list(range(0, len(ax_u2))) ]

# %%
def plot_data(ax, ay, az, time_millis):
    fig, axs = plt.subplots(3, figsize=(10,7))
    fig.suptitle('Ax, ay and az')
    axs[0].plot(time_millis, ax, color="red")
    axs[1].plot(time_millis, ay, color="green")
    axs[2].plot(time_millis, az, color="blue")
    plt.show()

plot_data(ax_u1, ay_u1, az_u1, time_millis_u1)

# %%
plot_data(ax_u2, ay_u2, az_u2, time_millis_u2)

# %%
# step 1 - peak finding on the z-axis

from scipy.signal import find_peaks

def get_peaks(az, time_scale, time_millis, distance=600):

    az_mean = np.mean(az)
    peaks,_ = find_peaks(az, distance= distance/time_scale, height = az_mean + 2)
    plt.plot(time_millis, az, color="blue", markevery=peaks, marker="o", label="points")
    plt.title("Az - peak finding")
    plt.show()
    print(f"peaks indices = {peaks}")
    print(f"peaks values = { [ round(az[peak],2) for peak in peaks ]}")
    return peaks

# %%
peaks_u1 = get_peaks(az_u1, time_scale, time_millis_u1)
# Out:
# peaks indices = [ 19  57  95 134 171 208 249]
# peaks values = [11, 11, 10, 8, 11, 9, 9]

# %%
# decrease distance required between peaks because u2 takes faster steps
peaks_u2 = get_peaks(az_u2, time_scale, time_millis_u2, distance=500)
# Out:
# peaks indices = [ 12  38  66  92 117 144 169]
# peaks values = [7, 7, 7, 6, 6, 7, 5]

# %%
# step 2 - create sliding windows centred around the peak

# total no. of readings to take

def generate_windows(ax, ay, az, time_scale, time_millis, peaks, num_readings=40):
    print(f"window time = {num_readings * time_scale}ms")
    # windows store the az readings for various windows
    windows = []
    window_times = []
    for peak in peaks:
        window, window_time = [], []
        # include half of the readings on either side of the peak
        lower = int(peak - num_readings/2)
        upper = int(peak + num_readings/2)
        # each window is of the format [ ax0, ay0, az0, ax1, ay1, az1, ... , axn, ayn, azn ]
        # consisting of n readings centred around the strike point in the z-axis
        for i in range(lower, upper):
            curr = [ round(ax[i], 2), round(ay[i], 2), round(az[i], 2) ]
            window.extend(curr)
            window_time.append(time_millis[i])
        windows.append(window)
        window_times.append(window_time)
    return windows, window_times

windows_u1, _ = generate_windows(ax_u1, ay_u1, az_u1, time_scale, time_millis_u1, peaks_u1, num_readings=20)
windows_u2, _ = generate_windows(ax_u2, ay_u2, az_u2, time_scale, time_millis_u2, peaks_u2, num_readings=20)

print(f"len(windows_u1)={len(windows_u1)}")
print(f"len(windows_u2)={len(windows_u1)}")
# Out:
# window time = 400ms
# window time = 400ms
# len(windows_u1)=7
# len(windows_u2)=7

# %%
from sklearn.model_selection import train_test_split

# step 3: split the dataset into training and testing modes

X = windows_u1 + windows_u2
y = ["u1"] * len(windows_u1) + ["u2"] * len(windows_u2)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn import svm
from sklearn.metrics import plot_confusion_matrix

# step 4: train and test a simple SVM classifier
clf = svm.SVC()
clf.fit(X_train, y_train)
plot_confusion_matrix(clf, X_test, y_test)
plt.title("Classifying U1's gait vs U2's gait")
plt.show()
